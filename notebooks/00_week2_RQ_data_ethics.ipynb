# %% [markdown]
# # Research Question, Dataset, and Ethics Check
#
# Use this notebook to document three things for your proposed research project:
#
# 1. Your research question
# 2. The dataset you plan to use
# 3. The ethical aspects you have considered
#
# > Do not load or analyse the data in this notebook. Choose a dataset, provide a reliable reference link, explain why you chose it, and answer the ethics questions using the dataset documentation and any relevant research literature. If a question is not applicable, write N/A and explain why.
#
# ## 1. Research Question
#
# - **Main research question:** [Write clear, focused questions that can be investigated using data.]
# - **Why is this question interesting or important?** [Write one or two sentences.]
# - **Who might use or care about the answer?** [Identify relevant people, communities, organisations, or decision-makers.]
# - **Possible sub-questions:** [List any smaller questions that help answer the main question.]
#
# ## 2. Dataset Reference
#
# - **Dataset name:** [ADD DATASET NAME]
# - **Source link:** [ADD URL, DOI, catalogue entry, or other reliable reference]
# - **Date accessed:** [YYYY-MM-DD]
# - **Who published or collected it?** [ADD PERSON, ORGANISATION, or UNKNOWN]
# - **Why did you choose this dataset?** [Write one or two sentences explaining how it relates to your research question and why it is suitable.]
# - **Evidence or notes:** [Add links, citations, or brief notes that support your choice.]

# %% [markdown]
# ## Research Questions and Answers
#
# For every answer, distinguish between **known evidence**, **reasonable interpretation**, and **unknown information to investigate**.
#
# ### 1. Where did the data come from?
#
# **Answer:** [Describe the original source, collection method, owner, URL/DOI, and date accessed. Cite evidence where possible.]
#
# ### 2. Why was it originally collected?
#
# **Answer:** [State the original purpose. If the current project uses it for a different purpose, explain that change and whether it is ethically justified.]
#
# ### 3. Who is represented?
#
# **Answer:** [Describe the population, groups, locations, time period, and sampling frame represented by the data.]
#
# ### 4. Who might be missing?
#
# **Answer:** [Identify groups excluded by the sampling method, missing responses, access barriers, non-response, or incomplete records.]
#
# ### 5. What personal or sensitive information does it contain, explicitly or implicitly?
#
# **Answer:** [List direct identifiers and sensitive fields. Also identify combinations of fields that could identify people or act as proxies for sensitive attributes.]
#
# ### 6. What could your analysis reveal that was not obvious in the original data?
#
# **Answer:** [Describe possible inferences, correlations, predictions, re-identification risks, or conclusions about individuals or groups.]
#
# ### 7. Who could benefit from your findings?
#
# **Answer:** [Identify individuals, groups, or organizations that could gain from the insights provided by your analysis.]
#
# The primary beneficiaries are E-commerce retailers, marketing teams and UX/UI teams.Retailers can use these models to help predict people's purchasing power or intent; in addition, they can get a better overview of how to predict consumers' buying habits and thus improve revenue through more personalised targeting.Similarly, marketing teams can use this data to tailor information by creating 'segments' that divide customers into distinct groups to focus marketing efforts on more favourable segments. Furthermore, marketing teams use this data to analyse the best times of day to send promotions and communications using the invoice time feature.UX and UI teams can use behavioural predictors such as previous order cancellations to better understand how the customer navigates their retail website. Descriptions of previously bought items can be used to adjust algorithms to push more personalised items.[1] Y. Kiki and V. Houndji, "Prediction of the Purchase Intention of Users on ECommerce Platforms using Gradient Boosting," International Journal of Engineering and Advanced Technology, vol. 10, pp. 446–450, Oct. 2020, doi: 10.35940/ijeat.A1929.1010120.
# [2] J. M. John, O. Shobayo, and B. Ogunleye, "An Exploration of Clustering Algorithms for Customer Segmentation in the UK Retail Market," Analytics, vol. 2, no. 4, pp. 809–823, Dec. 2023, doi: 10.3390/analytics2040042.
# [3] Q. Xin, "Self-Supervised Customer Representation Learning for Segmentation and Next-Purchase Prediction on UCI Online Retail," J-INTECH, vol. 14, pp. 20–37, Apr. 2026, doi: 10.32664/j-intech.v14i01.2229.
# [4] C. O. Sakar, S. O. Polat, M. Katircioglu, and Y. Kastro, "Real-time prediction of online shoppers' purchasing intention using multilayer perceptron and LSTM recurrent neural networks," Neural Comput & Applic, vol. 31, no. 10, pp. 6893–6908, Oct. 2019, doi: 10.1007/s00521-018-3523-0.### 8. Who could be harmed or misrepresented?
#
# **Answer:** [Identify people or groups who could experience privacy loss, discrimination, stigma, exclusion, incorrect decisions, or misleading representation.]
#
# Consumers could be harmed by revealing sensitive health and lifestyle information through their purchasing decisions, without knowing their knowledge or consent. This dataset tracks descriptions of each consumer's purchases, which increases the risk that models are being used to infer personal attributes such as gender, race and age, with inferred demographics being used to target ads and marketing.  [1].
# [1] A. Berke, K. Larson, S. Pentland, and D. Calacci, “Measuring risks inherent to our digital economies using Amazon purchase histories from US consumers,” Feb. 26, 2025, arXiv: arXiv:2502.18774. doi: 10.48550/arXiv.2502.18774.
